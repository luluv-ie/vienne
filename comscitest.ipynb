# %% [markdown]
# <a href="https://colab.research.google.com/github/luluv-ie/vienne/blob/main/comscitest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("i hold in me the power of twinks")
# Out:
# i hold in me the power of twinks
