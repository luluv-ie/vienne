# %% [markdown]
# <a href="https://colab.research.google.com/github/luluv-ie/vienne/blob/main/Maxnum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))
num3 = int(input("Enter a number: "))

# Determine the largest number
largest = max(num1, num2, num3)
print("The largest number is", largest)
# Out:
# Enter a number: 13
# Enter a number: 15
# Enter a number: 7
# The largest number is 15
